# %%
import os
os.environ['PROJ_LIB'] = '/usr/local/anaconda3/share/proj'
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import colors
import glob
import math

# %%
def yearly_csv ( _year ):
    _csvfiles = glob.glob ( str ( int ( _year ) ) + "/*.csv" )
    print ( len ( _csvfiles ) )
    _cleaned = [ x for x in _csvfiles if "ly" not in x ]
    print ( len ( _cleaned ) )
    return ( _cleaned )

# %%
def monthly_rainfall ( _csv, _year_month ):
    _rainfall = pd.read_csv ( _csv )
    _monthly_rainfall = _rainfall [ _rainfall [ 'Date' ].str.contains ( _year_month ) ]
    return ( _monthly_rainfall )

# %%
def station_loc ( _path ):
    _station_data = pd.read_csv ( _path, sep = ';|\t', header = None, engine = 'python' )
    lat = float ( _station_data.iloc [ 1, 1 ] )
    lon = float ( _station_data.iloc [ 2, 1 ] )
    return ( lat, lon )

# %%
def distance ( lat1, lon1, lat2, lon2 ):
    R = 6377.083
    
    dLat = math.radians(lat2 - lat1)
    dLon = math.radians(lon2 - lon1)
    lat1 = math.radians(lat1)
    lat2 = math.radians(lat2)
 
    a = math.sin ( dLat / 2.0 ) ** 2.0 + math.cos ( lat1 ) * math.cos ( lat2 ) * math.sin ( dLon / 2.0 ) ** 2.0
    c = 2 * math.asin ( math.sqrt ( a ) )
 
    return ( R * c )

# %%
index_dict = pd.read_csv ( 'FilePathDictionary.csv', names = [ 'Index', 'Station' ], header = None, skiprows = 1 )
index_dict = index_dict [ index_dict [ 'Index' ].isin ( common ) ]

# %%
_stations = index_dict [ 'Station' ].tolist ( )
stations_lat = [ ]
stations_lon = [ ]
for i in _stations:
    _loc = station_loc ( i )
    stations_lat.append ( _loc [ 0 ] )
    stations_lon.append ( _loc [ 1 ] )

# %%
years = '2013'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )

# %%
years = '2014'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )

# %%
years = '2015'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )

# %%
years = '2016'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )

# %%
years = '2017'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
origlen = [ ]
newlen = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    print ( '# of stations for 2017 - ' + str ( len ( csv_files ) ) )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _origlen = 0
        _newlen = 0
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _origlen += len ( _station_rainfall )
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            _newlen += len ( _station_rainfall )
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    origlen.append ( _origlen )
    newlen.append ( _newlen )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )

# %%
years = '2018'
month = [ '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12' ]
outliers = [ ]
for _month in month:
    year_month = years + '-' + _month
    csv_files = yearly_csv ( years )
    rainfall_limit = 4064
    station_rainfall = [ ]
    means = [ ]
    stds = [ ]
    rainsum = [ ]
    for i in csv_files:
        _station_rainfall = monthly_rainfall ( i, year_month )
        try:
            _station_rainfall = _station_rainfall [ _station_rainfall [ 'Rainfall(mm)' ] < rainfall_limit ]
            means.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            stds.append ( _station_rainfall [ 'Rainfall(mm)' ].mean ( ) )
            rainsum += _station_rainfall [ 'Rainfall(mm)' ].tolist ( )
        except:
            pass
    allmeans = np.array ( rainsum ).mean ( )
    allstd = np.array ( rainsum ).std ( )
    for i in range ( len ( means ) ):
        if ( means [ i ] > allmeans + 2 * allstd ):
            outliers.append ( csv_files [ i ] )
outliers = set ( [ int ( i [ 5 : -4 ] ) for i in outliers ] )
list ( outliers )
